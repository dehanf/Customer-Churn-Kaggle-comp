# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../output/feature_encoded.csv')

# %%
y = df[df.Churn.notna()].pop('Churn')
X = df[df.Churn.notna()]
test = df[df.Churn.isna()].copy().drop('Churn',axis =1,inplace = True)

# %%
from sklearn.model_selection import train_test_split

X_train,y_train,X_val,y_val = train_test_split(X,y,test_size = 0.2)
